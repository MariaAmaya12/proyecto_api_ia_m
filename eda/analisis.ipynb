# %%
import pandas as pd
from eda import ejecutar_eda

# Cargar la base de datos
df = pd.read_csv("data_limpia.csv")  # Asegúrate que el CSV esté en la misma carpeta que el notebook

# Ejecutar todo el análisis exploratorio
ejecutar_eda(df)
# Out:
# === INFORMACIÓN GENERAL ===
# Dimensiones: (5945, 8)
#
# Tipos de datos:
# tipo              str
# descripcion       str
# habitaciones    int64
# banos           int64
# area            int64
# barrio            str
# upz               str
# valor           int64
# dtype: object
#
# === VALORES NULOS ===
# Series([], dtype: int64)
#
# === VARIABLES NUMÉRICAS ===
#
# --- habitaciones ---
# count    5945.000000
# mean        3.158789
# std         2.312705
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max       110.000000
# Name: habitaciones, dtype: float64
# --- banos ---
# count    5945.000000
# mean        2.545669
# std         1.292634
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         9.000000
# Name: banos, dtype: float64
# --- area ---
# count      5945.000000
# mean        165.736754
# std        2175.883092
# min           2.000000
# 25%          60.000000
# ...

# %%
df = pd.read_csv("data_limpia.csv")

# %% [markdown]
# ANALISIS EXPLORATORIO DE LA BASE DE DATOS INMUEBLES EN BOGOTA

# %%
import pandas as pd
from eda import info_general, analizar_nulos, analizar_numericas, analizar_categoricas, matriz_correlacion

# %%
df = pd.read_csv("data_limpia.csv")  # o pd.read_excel("data_limpia.xlsx") si es Excel

# %%
info_general(df)
# Out:
# === INFORMACIÓN GENERAL ===
# Dimensiones: (5945, 8)
#
# Tipos de datos:
# tipo              str
# descripcion       str
# habitaciones    int64
# banos           int64
# area            int64
# barrio            str
# upz               str
# valor           int64
# dtype: object

# %%
analizar_nulos(df)
# Out:
# === VALORES NULOS ===
# Series([], dtype: int64)

# %%
analizar_numericas(df)
# Out:
# === VARIABLES NUMÉRICAS ===
#
# --- habitaciones ---
# count    5945.000000
# mean        3.158789
# std         2.312705
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max       110.000000
# Name: habitaciones, dtype: float64
# --- banos ---
# count    5945.000000
# mean        2.545669
# std         1.292634
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         9.000000
# Name: banos, dtype: float64
# --- area ---
# count      5945.000000
# mean        165.736754
# std        2175.883092
# min           2.000000
# 25%          60.000000
# 50%          87.000000
# 75%         151.000000
# max      166243.000000
# Name: area, dtype: float64
# --- valor ---
# count    5.945000e+03
# mean     6.545029e+08
# std      7.653919e+08
# min      6.000000e+07
# 25%      2.750000e+08
# 50%      4.490000e+08
# 75%      7.500000e+08
# max      1.600000e+10
# Name: valor, dtype: float64

# %%
analizar_categoricas(df)
# Out:
# === VARIABLES CATEGÓRICAS ===
#
# --- tipo ---
# tipo
# Apartamento            4458
# Casa                   1383
# Oficina/Consultorio      42
# Local                    29
# Edificio                 16
# Name: count, dtype: int64
#
# --- descripcion ---
# descripcion
# Apartamento en venta en Usaquén               575
# Apartamento en venta en Zona Noroccidental    347
# Apartamento en venta en Cedritos              309
# Apartamento en venta en Barrios Unidos        234
# Apartamento en venta en Santa Barbara         220
# Name: count, dtype: int64
#
# --- barrio ---
# barrio
# Usaquén               699
# Zona Noroccidental    516
# Cedritos              348
# Kennedy               341
# Barrios Unidos        337
# Name: count, dtype: int64
#
# --- upz ---
# upz
# Usaquén                                  1067
# CHAPINERO: Pardo Rubio + Chapinero        805
# USAQUÉN: Country Club + Santa Bárbara     480
# CHAPINERO: Chicó Lago + El Refugio        390
# ...

# %%
matriz_correlacion(df)
# Out:
# === MATRIZ DE CORRELACIÓN ===
#               habitaciones     banos      area     valor
# habitaciones      1.000000  0.468719  0.031135  0.226013
# banos             0.468719  1.000000  0.048085  0.560630
# area              0.031135  0.048085  1.000000  0.048184
# valor             0.226013  0.560630  0.048184  1.000000
